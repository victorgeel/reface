# %% [markdown]
# <a href="https://colab.research.google.com/github/victorgeel/reface/blob/main/ReFaceVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/victorgeel/reface --branch victorgeel-patch-1 --single-branch
# %cd reface
# !pip install git+https://github.com/jupyterhub/binderhub

# !pip install -r requirements.txt
# Out:
# Cloning into 'reface'...
# remote: Enumerating objects: 352, done.
# remote: Counting objects: 100% (157/157), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 352 (delta 118), reused 121 (delta 101), pack-reused 195
# Receiving objects: 100% (352/352), 3.73 MiB | 24.20 MiB/s, done.
# Resolving deltas: 100% (199/199), done.
# /content/reface
# ...
#   Cloning https://github.com/jupyterhub/binderhub to /tmp/pip-req-build-vw9snacd
#   Running command git clone --filter=blob:none --quiet https://github.com/jupyterhub/binderhub /tmp/pip-req-build-vw9snacd
#   Resolved https://github.com/jupyterhub/binderhub to commit 46f5d0e9cdf8c79dd8c28556dae5b7e3cb402788
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 49.0 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall numpy -y -q
# !pip install --disable-pip-version-check --root-user-action=ignore ngrok ffmpeg numpy==1.24.3 onnxruntime-gpu gradio insightface==0.7.3 ffmpeg_python opencv_python -q --force
# !!wget --content-disposition "https://github.com/facefusion/facefusion-assets/releases/download/models/inswapper_128.onnx"
# !python app.py --share_gradio --colab_performance
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# bigframes 0.16.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.1.4 which is incompatible.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2023.12.2 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.1.4 which is incompatible.
# tensorboard 2.15.1 requires protobuf<4.24,>=3.19.6, but you have protobuf 4.25.1 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.25.1 which is incompatible.
# ...
